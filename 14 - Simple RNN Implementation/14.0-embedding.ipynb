# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
    ]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[2707, 6227, 666, 9641],
#  [2707, 6227, 666, 3492],
#  [2707, 2807, 666, 6590],
#  [9873, 8084, 2705, 5210, 2153],
#  [9873, 8084, 2705, 5210, 4476],
#  [5671, 2707, 1288, 666, 9938],
#  [9121, 1911, 1741, 5210]]

# %%
## word Embedding Representation
from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2707 6227  666 9641]
#  [   0    0    0    0 2707 6227  666 3492]
#  [   0    0    0    0 2707 2807  666 6590]
#  [   0    0    0 9873 8084 2705 5210 2153]
#  [   0    0    0 9873 8084 2705 5210 4476]
#  [   0    0    0 5671 2707 1288  666 9938]
#  [   0    0    0    0 9121 1911 1741 5210]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\Users\emon1\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# array([[[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [ 0.02842833, -0.01406129,  0.03849218, -0.04979625,
#           0.01641433,  0.04243883,  0.0169812 , -0.01841973,
#          -0.01759195, -0.01810206],
#         [-0.01692034,  0.02246938,  0.00097597, -0.00309061,
#          -0.03197696, -0.03912841, -0.0107704 ,  0.01140379,
#          -0.0202571 ,  0.00645455],
#         [ 0.04126879,  0.0142425 , -0.03168526, -0.02349491,
#           0.00281946,  0.03933154,  0.04276798, -0.04197158,
#          -0.02617842,  0.01876947],
#         [-0.02205619, -0.01007482,  0.03596627,  0.00666826,
#           0.03263075, -0.0455531 ,  0.03336759, -0.04716767,
#           0.00217358,  0.02438581]],
#
#        [[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [ 0.02842833, -0.01406129,  0.03849218, -0.04979625,
#           0.01641433,  0.04243883,  0.0169812 , -0.01841973,
#          -0.01759195, -0.01810206],
#         [-0.01692034,  0.02246938,  0.00097597, -0.00309061,
#          -0.03197696, -0.03912841, -0.0107704 ,  0.01140379,
#          -0.0202571 ,  0.00645455],
#         [ 0.04126879,  0.0142425 , -0.03168526, -0.02349491,
#           0.00281946,  0.03933154,  0.04276798, -0.04197158,
#          -0.02617842,  0.01876947],
#         [ 0.02791287,  0.04133821, -0.00254308, -0.02203343,
#           0.03022188, -0.04952649, -0.00075771, -0.00942624,
#          -0.03754672,  0.02928339]],
#
#        [[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [ 0.02842833, -0.01406129,  0.03849218, -0.04979625,
#           0.01641433,  0.04243883,  0.0169812 , -0.01841973,
#          -0.01759195, -0.01810206],
#         [ 0.03840687, -0.03629398,  0.01029414, -0.01321935,
#           0.04346411,  0.01210699, -0.04867101, -0.02609069,
#           0.03956265,  0.01146553],
#         [ 0.04126879,  0.0142425 , -0.03168526, -0.02349491,
#           0.00281946,  0.03933154,  0.04276798, -0.04197158,
#          -0.02617842,  0.01876947],
#         [ 0.00396625, -0.02339156,  0.04473308, -0.01330291,
#           0.02804447, -0.02756155, -0.01420278, -0.04233465,
#           0.01731143, -0.00137698]],
#
#        [[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.00630093, -0.03493608, -0.01845968, -0.04733321,
#          -0.04124489, -0.00311544, -0.00979266, -0.00049635,
#           0.0094901 , -0.0082403 ],
#         [-0.040935  , -0.0416222 , -0.04503998, -0.03560436,
#           0.00878513,  0.02666917,  0.01770854, -0.02800093,
#          -0.04002319,  0.00226841],
#         [-0.04001563,  0.00472737, -0.03560833,  0.01389129,
#          -0.0196934 ,  0.01858009, -0.04144321,  0.04272813,
#           0.04846728, -0.01300203],
#         [-0.00897268,  0.00945983,  0.02141169,  0.04097782,
#          -0.01671724,  0.02230061,  0.03775898,  0.00916785,
#           0.04001082,  0.03443476],
#         [ 0.00519926,  0.02337975,  0.04343735, -0.04565493,
#           0.04356786,  0.01218617, -0.02639816,  0.0133306 ,
#           0.01289762,  0.04948429]],
#
#        [[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.00630093, -0.03493608, -0.01845968, -0.04733321,
#          -0.04124489, -0.00311544, -0.00979266, -0.00049635,
#           0.0094901 , -0.0082403 ],
#         [-0.040935  , -0.0416222 , -0.04503998, -0.03560436,
#           0.00878513,  0.02666917,  0.01770854, -0.02800093,
#          -0.04002319,  0.00226841],
#         [-0.04001563,  0.00472737, -0.03560833,  0.01389129,
#          -0.0196934 ,  0.01858009, -0.04144321,  0.04272813,
#           0.04846728, -0.01300203],
#         [-0.00897268,  0.00945983,  0.02141169,  0.04097782,
#          -0.01671724,  0.02230061,  0.03775898,  0.00916785,
#           0.04001082,  0.03443476],
#         [ 0.01550462,  0.02384833, -0.00091255, -0.01045918,
#          -0.04468875, -0.01310746, -0.01566839, -0.04130472,
#           0.0390023 , -0.01193338]],
#
#        [[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [ 0.00486243, -0.02250645, -0.01968068, -0.03088037,
#          -0.01366905, -0.03061994, -0.03950025,  0.00532449,
#           0.04239681, -0.01156126],
#         [ 0.02842833, -0.01406129,  0.03849218, -0.04979625,
#           0.01641433,  0.04243883,  0.0169812 , -0.01841973,
#          -0.01759195, -0.01810206],
#         [-0.00671234,  0.0469485 ,  0.03111729,  0.0191831 ,
#           0.04909886, -0.04074804, -0.04112904,  0.04256063,
#          -0.03316112, -0.01511183],
#         [ 0.04126879,  0.0142425 , -0.03168526, -0.02349491,
#           0.00281946,  0.03933154,  0.04276798, -0.04197158,
#          -0.02617842,  0.01876947],
#         [-0.04000502,  0.02224033, -0.01848134, -0.03141167,
#          -0.01256641, -0.03458191,  0.01385516, -0.03351676,
#           0.01592823,  0.00589508]],
#
#        [[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.00771691, -0.03168298, -0.03327537, -0.04542118,
#           0.0251354 ,  0.02017165, -0.04769893, -0.00903564,
#          -0.03598399, -0.03597437],
#         [-0.02287898, -0.02467536, -0.00499705, -0.03979485,
#          -0.00195987, -0.0064914 ,  0.02652894,  0.00299625,
#           0.03092248, -0.04987882],
#         [-0.01604955, -0.02223281,  0.0180125 , -0.04246074,
#           0.01232906,  0.01915551, -0.03007758,  0.03340336,
#          -0.04898332, -0.0100354 ],
#         [-0.00897268,  0.00945983,  0.02141169,  0.04097782,
#          -0.01671724,  0.02230061,  0.03775898,  0.00916785,
#           0.04001082,  0.03443476]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 2707, 6227,  666, 9641])

# %%
model.predict(np.array([embedded_docs[0]]))  # Wrap it in a list or array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# array([[[-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [-0.02250229, -0.01567499,  0.01184778, -0.01407897,
#           0.00241465,  0.00666957, -0.03401119,  0.03956569,
#           0.03536751,  0.03385286],
#         [ 0.02842833, -0.01406129,  0.03849218, -0.04979625,
#           0.01641433,  0.04243883,  0.0169812 , -0.01841973,
#          -0.01759195, -0.01810206],
#         [-0.01692034,  0.02246938,  0.00097597, -0.00309061,
#          -0.03197696, -0.03912841, -0.0107704 ,  0.01140379,
#          -0.0202571 ,  0.00645455],
#         [ 0.04126879,  0.0142425 , -0.03168526, -0.02349491,
#           0.00281946,  0.03933154,  0.04276798, -0.04197158,
#          -0.02617842,  0.01876947],
#         [-0.02205619, -0.01007482,  0.03596627,  0.00666826,
#           0.03263075, -0.0455531 ,  0.03336759, -0.04716767,
#           0.00217358,  0.02438581]]], dtype=float32)
